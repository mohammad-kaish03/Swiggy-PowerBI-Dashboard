# %% [markdown]
# # bussines problem
# - answer given questions and analys accorfing to them

# %% [markdown]
# # data collecting

# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8")

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel("SWIGGY INSTAMART DATA.xlsx")
df
# Out:
#      Fat Content Item Identifier     Item Type  Outlet Establishment Year  \
# 0        Regular           FDX32    Vegetables                       2012
# 1        Low Fat           NCB42  Health Items                       2022
# 2        Regular           FDR28  Frozen Foods                       2016
# 3        Regular           FDL50        Canned                       2014
# 4        Low Fat           DRI25   Soft Drinks                       2015
# ...          ...             ...           ...                        ...
# 8518     low fat           NCT53  Health Items                       2018
# 8519     low fat           FDN09        Snacks                       2018
# 8520     low fat           DRE13   Soft Drinks                       2018
# 8521         reg           FDT50         Dairy                       2018
# 8522         reg           FDM58        Snacks                       2018
#
#      Outlet Identifier Outlet Location Type Outlet Size        Outlet Type  \
# ...

# %% [markdown]
# # data understanding

# %% [markdown]
# ## understanding columns

# %%
df.columns.to_list()
# Out:
# ['Fat Content',
#  'Item Identifier',
#  'Item Type',
#  'Outlet Establishment Year',
#  'Outlet Identifier',
#  'Outlet Location Type',
#  'Outlet Size',
#  'Outlet Type',
#  'Item Visibility',
#  'Item Weight',
#  'Sales',
#  'Rating']

# %%
df.describe()
# Out:
#        Outlet Establishment Year  Item Visibility  Item Weight        Sales  \
# count                8523.000000      8500.000000  7059.000000  8523.000000
# mean                 2016.450546         0.066112    12.856534   140.992783
# std                     3.189396         0.051620     4.642847    62.275067
# min                  2011.000000         0.000000     4.555000    31.290000
# 25%                  2014.000000         0.026953     8.772500    93.826500
# 50%                  2016.000000         0.053904    12.600000   143.012800
# 75%                  2018.000000         0.094618    16.850000   185.643700
# max                  2022.000000         0.328391    21.350000   266.888400
#
#             Rating
# count  8523.000000
# mean      3.965857
# std       0.605651
# min       1.000000
# 25%       4.000000
# 50%       4.000000
# 75%       4.200000
# max       5.000000

# %%
df.dtypes
# Out:
# Fat Content                   object
# Item Identifier               object
# Item Type                     object
# Outlet Establishment Year      int64
# Outlet Identifier             object
# Outlet Location Type          object
# Outlet Size                   object
# Outlet Type                   object
# Item Visibility              float64
# Item Weight                  float64
# Sales                        float64
# Rating                       float64
# dtype: object

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Fat Content                8523 non-null   object
#  1   Item Identifier            8523 non-null   object
#  2   Item Type                  8523 non-null   object
#  3   Outlet Establishment Year  8523 non-null   int64
#  4   Outlet Identifier          8523 non-null   object
#  5   Outlet Location Type       8523 non-null   object
#  6   Outlet Size                8523 non-null   object
#  7   Outlet Type                8523 non-null   object
#  8   Item Visibility            8500 non-null   float64
#  9   Item Weight                7059 non-null   float64
#  10  Sales                      8523 non-null   float64
#  11  Rating                     8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# ### observation:
# - there is 12 columns
# - there is 8523 rows
# - there is some null values in item weight and item visibility

# %% [markdown]
# ## grouping by data types

# %%
continues = ['Item Visibility','Item Weight','Sales','Rating']
d_count = ['Outlet Establishment Year']
d_cat =['Fat Content','Item Identifier','Item Type','Outlet Location Type','Outlet Size','Outlet Type','Outlet Identifier']

# %% [markdown]
# ### observation:
# - we have 4 continues variables
# - we have 1 discrete count variable
# - we have 7 discrete catagorical variables

# %% [markdown]
# ## understanding every columns

# %% [markdown]
# ## for discrete variables

# %%
for i in d_cat:
    print("\n",i,' the unique values are:' ,df[i].unique())
    print(i,'the value count are:',df[i].value_counts())
# Out:
#  Fat Content  the unique values are: ['Regular' 'Low Fat' 'low fat' 'LF' 'reg']
# Fat Content the value count are: Fat Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64
#
#  Item Identifier  the unique values are: ['FDX32' 'NCB42' 'FDR28' ... 'FDU60' 'NCX53' 'FDE52']
# Item Identifier the value count are: Item Identifier
# FDW13    10
# FDG33    10
# FDX20     9
# NCL31     9
# FDQ40     9
#          ..
# FDN52     1
# FDQ60     1
# FDT35     1
# FDK57     1
# FDE52     1
# Name: count, Length: 1559, dtype: int64
#
#  Item Type  the unique values are: ['Vegetables' 'Health Items' 'Frozen Foods' 'Canned' 'Soft Drinks'
#  'Household' 'Snacks' 'Meat' 'Breads' 'Drinks' 'Others' 'Dairy'
#  'Breakfast' 'Baking Goods' 'Seafood' 'Starchy Foods']
# Item Type the value count are: Item Type
# Vegetables       1232
# Snacks           1200
# Household         910
# Frozen Foods      856
# Dairy             682
# ...

# %%
sns.histplot(df["Fat Content"])
# Out:
# <Axes: xlabel='Fat Content', ylabel='Count'>

# %%
sns.histplot(df["Item Type"])
plt.xticks(rotation=90)
plt.show()

# %%
sns.histplot(df["Outlet Location Type"])
# Out:
# <Axes: xlabel='Outlet Location Type', ylabel='Count'>

# %%
sns.histplot(df["Outlet Size"])
# Out:
# <Axes: xlabel='Outlet Size', ylabel='Count'>

# %%
sns.histplot(df["Outlet Type"])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### observation:
# -           in discrete variables
# - Fat Content___________: there is 5 unique values
# - Item Identifier_______: there is 1559 unique values
# - Item Type_____________: there is 16 unique values
# - Outlet Location Type__: there is 3 unique values
# - Outlet Size___________: there is 3 unique values
# - Outlet Type___________: there is 4 unique values
# - Outlet Identifier_____: there is 10 unique values

# %% [markdown]
# ## for continoues variables

# %%
df[continues].describe()
# Out:
#        Item Visibility  Item Weight        Sales       Rating
# count      8500.000000  7059.000000  8523.000000  8523.000000
# mean          0.066112    12.856534   140.992783     3.965857
# std           0.051620     4.642847    62.275067     0.605651
# min           0.000000     4.555000    31.290000     1.000000
# 25%           0.026953     8.772500    93.826500     4.000000
# 50%           0.053904    12.600000   143.012800     4.000000
# 75%           0.094618    16.850000   185.643700     4.200000
# max           0.328391    21.350000   266.888400     5.000000

# %% [markdown]
# ## for discrete count

# %%
df["Outlet Establishment Year"].unique()
# Out:
# array([2012, 2022, 2016, 2014, 2015, 2020, 2011, 2018, 2017])

# %%
df["Outlet Establishment Year"].value_counts()
# Out:
# Outlet Establishment Year
# 2018    1463
# 2014     932
# 2012     930
# 2017     930
# 2016     930
# 2015     929
# 2022     928
# 2020     926
# 2011     555
# Name: count, dtype: int64

# %%
sns.histplot(df["Outlet Establishment Year"])
# Out:
# <Axes: xlabel='Outlet Establishment Year', ylabel='Count'>

# %% [markdown]
# ### observation:
# - Outlet Establishment Year  :  has 9 unique years value

# %% [markdown]
# # Apply Descriptive Statistics

# %%
df[continues].describe()
# Out:
#        Item Visibility  Item Weight        Sales       Rating
# count      8500.000000  7059.000000  8523.000000  8523.000000
# mean          0.066112    12.856534   140.992783     3.965857
# std           0.051620     4.642847    62.275067     0.605651
# min           0.000000     4.555000    31.290000     1.000000
# 25%           0.026953     8.772500    93.826500     4.000000
# 50%           0.053904    12.600000   143.012800     4.000000
# 75%           0.094618    16.850000   185.643700     4.200000
# max           0.328391    21.350000   266.888400     5.000000

# %%
df[continues].skew()
# Out:
# Item Visibility    1.168132
# Item Weight        0.082505
# Sales              0.127202
# Rating            -2.188976
# dtype: float64

# %% [markdown]
# ### observation:
# - Item Visibility____1.168132____(is right skewed)
# - Item Weight________0.082426____(is normally distributed)
# - Sales______________0.127202____(is normally distributed)
# - Rating____________-2.188976____(is left skewed)

# %%
sns.histplot(df["Item Visibility"],kde=1)
plt.show()

# %% [markdown]
# ### observation:
# #### Item Visibility
# - more data belongs inbetween 0 to 0.05
# - minimum data belongs inbetween 0.25 to 0.30

# %%
sns.histplot(df["Item Weight"],kde=1)
plt.show()

# %% [markdown]
# ### observation:
# #### Item Weight
# - it is normally distributed data

# %%
sns.histplot(df["Sales"],kde=1)
plt.show()

# %% [markdown]
# ### observation:
# #### Sales
# - it is normally distributed data

# %%
sns.histplot(df["Rating"],kde=1)
plt.show()

# %% [markdown]
# ### observation:
# #### Rating
# - more data belongs to 4.0 rating

# %% [markdown]
# # data preproccessing

# %% [markdown]
# ## missing value

# %%
df.isnull().sum()
# Out:
# Fat Content                     0
# Item Identifier                 0
# Item Type                       0
# Outlet Establishment Year       0
# Outlet Identifier               0
# Outlet Location Type            0
# Outlet Size                     0
# Outlet Type                     0
# Item Visibility                23
# Item Weight                  1464
# Sales                           0
# Rating                          0
# dtype: int64

# %%
df.isnull().sum()/len(df)*100
# Out:
# Fat Content                   0.000000
# Item Identifier               0.000000
# Item Type                     0.000000
# Outlet Establishment Year     0.000000
# Outlet Identifier             0.000000
# Outlet Location Type          0.000000
# Outlet Size                   0.000000
# Outlet Type                   0.000000
# Item Visibility               0.269858
# Item Weight                  17.177050
# Sales                         0.000000
# Rating                        0.000000
# dtype: float64

# %%
df["Item Weight"].fillna(df["Item Weight"].median(),inplace=True)
df["Item Visibility"].fillna(df["Item Visibility"].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Fat Content                  0
# Item Identifier              0
# Item Type                    0
# Outlet Establishment Year    0
# Outlet Identifier            0
# Outlet Location Type         0
# Outlet Size                  0
# Outlet Type                  0
# Item Visibility              0
# Item Weight                  0
# Sales                        0
# Rating                       0
# dtype: int64

# %% [markdown]
# ### observation:
# - we got 1463 missing values as null in Item Weight (17%)
# - we got 23 missing values as null in Item Visibility (0.26%)
# - we replaced null values with median of the column

# %% [markdown]
# ## duplicate data

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### observation:
# - there was no duplicate records

# %% [markdown]
# ## wrong filling in fat contant

# %%
df["Fat Content"].unique()
# Out:
# array(['Regular', 'Low Fat', 'low fat', 'LF', 'reg'], dtype=object)

# %%
df["Fat Content"] = df["Fat Content"].replace('low fat', 'Low Fat')
df["Fat Content"] = df["Fat Content"].replace('reg', 'Regular')
df["Fat Content"] = df["Fat Content"].replace('LF', 'Low Fat')

# %% [markdown]
# ### observation:
# #### Fat Content
# - it has 5 unique values
# - 3 of them was miss-spelled
# - we replaced them with 2 unique values

# %% [markdown]
# ## outlier

# %%
sns.boxplot(df["Item Visibility"])
# Out:
# <Axes: ylabel='Item Visibility'>

# %% [markdown]
# ### observation:
# #### Item Visibility
# - it has outlier upperlimt with 0.20

# %%
sns.boxplot(df["Item Weight"])
# Out:
# <Axes: ylabel='Item Weight'>

# %% [markdown]
# ### observation:
# #### Item Weight
# - it has no outlier

# %%
sns.boxplot(df["Sales"])
# Out:
# <Axes: ylabel='Sales'>

# %% [markdown]
# ### observation:
# #### Sales
# - it has no outlier

# %%
sns.boxplot(df["Rating"])
# Out:
# <Axes: ylabel='Rating'>

# %% [markdown]
# ### observation:
# #### Rating
# - it has upperlimit of 4.5
# - it has lowerlimit of 3.5

# %% [markdown]
# # ANALYTICS

# %% [markdown]
# ## Q1: total sales

# %%
df["Sales"].sum()
# Out:
# np.float64(1201681.4928)

# %% [markdown]
# ## Q2: avg sales

# %%
df["Sales"].mean()
# Out:
# np.float64(140.99278338613163)

# %% [markdown]
# ## Q3: total sales of all items

# %%
a= df.groupby("Item Type")["Sales"].sum()
a.plot(kind="bar")
a
# Out:
# Item Type
# Baking Goods      81894.7364
# Breads            35379.1198
# Breakfast         15596.6966
# Canned            90706.7290
# Dairy            101276.4616
# Drinks            29334.6806
# Frozen Foods     118558.8814
# Health Items      68025.8388
# Household        135976.5254
# Meat              59449.8638
# Others            22451.8916
# Seafood            9077.8700
# Snacks           175433.9224
# Soft Drinks       58514.1670
# Starchy Foods     21880.0274
# Vegetables       178124.0810
# Name: Sales, dtype: float64

# %% [markdown]
# ## Q4: avg sales of all items

# %%
a= df.groupby("Item Type")["Sales"].mean()
a.plot(kind="bar")
# Out:
# <Axes: xlabel='Item Type'>

# %% [markdown]
# ## Q5 : total sales by establishment year

# %%
a= df.groupby("Outlet Establishment Year")["Sales"].sum()
a.plot(kind="bar")
a
# Out:
# Outlet Establishment Year
# 2011     78131.5666
# 2012    130476.8598
# 2014    131809.0156
# 2015    130942.7802
# 2016    132113.3698
# 2017    133103.9070
# 2018    204522.2570
# 2020    129103.9604
# 2022    131477.7764
# Name: Sales, dtype: float64

# %% [markdown]
# ## Q6 : avg sales by establishment year

# %%
a= df.groupby("Outlet Establishment Year")["Sales"].mean()
a.plot(kind="bar")
a
# Out:
# Outlet Establishment Year
# 2011    140.777597
# 2012    140.297699
# 2014    141.425982
# 2015    140.950248
# 2016    142.057387
# 2017    143.122481
# 2018    139.796485
# 2020    139.421124
# 2022    141.678638
# Name: Sales, dtype: float64

# %% [markdown]
# ## Q7: total sales of outlets by Outlest size

# %%
a = df.groupby(["Outlet Size","Outlet Size"]).agg({'Sales': ['sum']})
a.plot(kind="bar")
a
# Out:
#                                Sales
#                                  sum
# Outlet Size Outlet Size
# High        High         248991.5860
# Medium      Medium       507895.7364
# Small       Small        444794.1704

# %% [markdown]
# ## Q8: avg sales of outlets by Outlest size

# %%
a = df.groupby(["Outlet Size","Outlet Size"]).agg({'Sales': ['mean']})
a.plot(kind="bar")
a
# Out:
#                               Sales
#                                mean
# Outlet Size Outlet Size
# High        High         142.037414
# Medium      Medium       139.877647
# Small       Small        141.699322

# %% [markdown]
# ## Q9: total sales of outlets by Outlest type

# %%
a = df.groupby(["Outlet Type","Outlet Type"]).agg({'Sales': ['sum']})
a.plot(kind="bar")
a
# Out:
#                                            Sales
#                                              sum
# Outlet Type       Outlet Type
# Grocery Store     Grocery Store      151939.1490
# Supermarket Type1 Supermarket Type1  787549.8928
# Supermarket Type2 Supermarket Type2  131477.7764
# Supermarket Type3 Supermarket Type3  130714.6746

# %% [markdown]
# ## Q10: avg sales of outlets by Outlest type

# %%
a = df.groupby(["Outlet Type","Outlet Type"]).agg({'Sales': ['mean']})
a.plot(kind="bar")
a
# Out:
#                                           Sales
#                                            mean
# Outlet Type       Outlet Type
# Grocery Store     Grocery Store      140.294690
# Supermarket Type1 Supermarket Type1  141.213895
# Supermarket Type2 Supermarket Type2  141.678638
# Supermarket Type3 Supermarket Type3  139.801791

# %% [markdown]
# ## Q11 : total sales of outlets by fat contant

# %%
a = df.groupby(["Fat Content","Outlet Type"]).agg({'Sales': ['sum']})
a.plot(kind="bar")
a
# Out:
#                                      Sales
#                                        sum
# Fat Content Outlet Type
# Low Fat     Grocery Store       99814.3670
#             Supermarket Type1  507886.3014
#             Supermarket Type2   84844.6090
#             Supermarket Type3   83774.4110
# Regular     Grocery Store       52124.7820
#             Supermarket Type1  279663.5914
#             Supermarket Type2   46633.1674
#             Supermarket Type3   46940.2636

# %% [markdown]
# ## Q12 : avg sales of outlets by fat contant

# %%
sns.catplot(y=df["Sales"],x=df["Outlet Type"],kind="bar",hue=df["Fat Content"])
plt.xticks(rotation=90)
plt.show()

a = df.groupby(["Fat Content","Outlet Type"]).agg({'Sales': ['mean']})
a
# Out:
#                                     Sales
#                                      mean
# Fat Content Outlet Type
# Low Fat     Grocery Store      141.580662
#             Supermarket Type1  140.727709
#             Supermarket Type2  141.880617
#             Supermarket Type3  138.470101
# Regular     Grocery Store      137.896249
#             Supermarket Type1  142.105483
#             Supermarket Type2  141.312628
#             Supermarket Type3  142.243223

# %% [markdown]
# ## Q13 : total sales of outlets by item type

# %%
df.groupby(["Outlet Type","Item Type"]).agg({'Sales': ['sum']})
# Out:
#                                       Sales
#                                         sum
# Outlet Type       Item Type
# Grocery Store     Baking Goods   10747.2358
#                   Breads          4832.9448
#                   Breakfast       2793.5128
#                   Canned         10079.8990
#                   Dairy          13539.3398
# ...                                     ...
# Supermarket Type3 Seafood          868.1980
#                   Snacks         19806.7076
#                   Soft Drinks     5549.1114
#                   Starchy Foods   2003.0974
#                   Vegetables     20301.3866
#
# [64 rows x 1 columns]

# %% [markdown]
# ## Q14 : avg sales of outlets by item type

# %%
sns.catplot(x=df["Item Type"],y=df["Sales"],kind='bar',hue=df["Outlet Type"])
plt.xticks(rotation=90)
plt.show()

df.groupby(["Outlet Type","Item Type"]).agg({'Sales': ['mean']})
# Out:
#                                       Sales
#                                        mean
# Outlet Type       Item Type
# Grocery Store     Baking Goods   126.438068
#                   Breads         146.452873
#                   Breakfast      147.026989
#                   Canned         138.080808
#                   Dairy          147.166737
# ...                                     ...
# Supermarket Type3 Seafood        124.028286
#                   Snacks         144.574508
#                   Soft Drinks    123.313587
#                   Starchy Foods  143.078386
#                   Vegetables     145.009904
#
# [64 rows x 1 columns]

# %% [markdown]
# ## Q15 : avrage rating of itmes

# %%
a = df.groupby(["Item Type","Item Type"]).agg({'Rating': ['mean']})
a.plot(kind="bar")
a
# Out:
#                                Rating
#                                  mean
# Item Type     Item Type
# Baking Goods  Baking Goods   3.983025
# Breads        Breads         3.881275
# Breakfast     Breakfast      3.932727
# Canned        Canned         3.994299
# Dairy         Dairy          3.965836
# Drinks        Drinks         3.907477
# Frozen Foods  Frozen Foods   3.971145
# Health Items  Health Items   3.986154
# Household     Household      3.998681
# Meat          Meat           4.023059
# Others        Others         3.954438
# Seafood       Seafood        3.959375
# Snacks        Snacks         3.948917
# Soft Drinks   Soft Drinks    3.920674
# Starchy Foods Starchy Foods  3.920270
# Vegetables    Vegetables     3.956169

# %% [markdown]
# ## Q16 : avg rating of outlets

# %%
a = df.groupby(["Outlet Type","Outlet Type"]).agg({'Rating': ['mean']})
a.plot(kind="bar")
a
# Out:
#                                        Rating
#                                          mean
# Outlet Type       Outlet Type
# Grocery Store     Grocery Store      3.985873
# Supermarket Type1 Supermarket Type1  3.963242
# Supermarket Type2 Supermarket Type2  3.971228
# Supermarket Type3 Supermarket Type3  3.952941

# %% [markdown]
# ## Q17 : avg fat content overall

# %%
df["Fat Content"].value_counts().plot(kind="pie",autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>
